# %%
import pandas as pd
X=pd.read_csv(r"C:\Users\Arbaj\Desktop\Demo Datasets\Lesson 4\bigmart_train.csv")
Y=pd.read_csv(r"C:\Users\Arbaj\Desktop\Demo Datasets\Lesson 4\bigmart_test.csv")
X
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
X.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
Y
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
Y.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
X['Item_Weight']=X['Item_Weight'].fillna(X['Item_Weight'].mean())

# %%
X['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
X['Outlet_Size']=X['Outlet_Size'].fillna('Medium')

# %%
X.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
X['Item_Identifier']=X['Item_Identifier'].apply(lambda x:x[0:2])
X.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0              FD         9.30          Low Fat         0.016047        Dairy
# 1              DR         5.92          Regular         0.019278  Soft Drinks
# 2              FD        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
'Item_Fat_Content','Outlet_Location_Type','Outlet_Size','Item_Type_Combined','Outlet_Type','Outlet'
# Out:
# ('Item_Fat_Content',
#  'Outlet_Location_Type',
#  'Outlet_Size',
#  'Item_Type_Combined',
#  'Outlet_Type',
#  'Outlet')

# %%
from sklearn.preprocessing import LabelEncoder
L=LabelEncoder()

# %%
X['Outlet_Identifier']=L.fit_transform(X['Outlet_Identifier'])

# %%
X.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FD         9.30          Low Fat         0.016047
# 1              DR         5.92          Regular         0.019278
# 2              FD        17.50          Low Fat         0.016760
# 3              FD        19.20          Regular         0.000000
# 4              NC         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP  Outlet_Identifier  \
# 0                  Dairy  249.8092                  9
# 1            Soft Drinks   48.2692                  3
# 2                   Meat  141.6180                  9
# 3  Fruits and Vegetables  182.0950                  0
# 4              Household   53.8614                  1
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
L=LabelEncoder()
o=['Item_Identifier','Item_Fat_Content','Outlet_Size','Outlet_Location_Type','Outlet_Type']
for i in o:
    X[i]=L.fit_transform(X[i])

# %%
X
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.016047
# 1                   0        5.920                 2         0.019278
# 2                   1       17.500                 1         0.016760
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.056783
# 8519                1        8.380                 2         0.046982
# 8520                2       10.600                 1         0.035186
# 8521                1        7.210                 2         0.145221
# 8522                0       14.800                 1         0.044878
#
#                   Item_Type  Item_MRP  Outlet_Identifier  \
# 0                     Dairy  249.8092                  9
# ...

# %%
X.drop(columns=['Item_Type','Outlet_Establishment_Year'],inplace=True)

# %%
X.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0                1         9.30                 1         0.016047  249.8092
# 1                0         5.92                 2         0.019278   48.2692
# 2                1        17.50                 1         0.016760  141.6180
# 3                1        19.20                 2         0.000000  182.0950
# 4                2         8.93                 1         0.000000   53.8614
#
#    Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                  9            1                     0            1
# 1                  3            1                     2            2
# 2                  9            1                     0            1
# 3                  0            1                     2            0
# 4                  1            0                     2            1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# ...

# %%
X=pd.get_dummies(X,columns=['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type'])
X
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# 0           9.300         0.016047  249.8092          3735.1380
# 1           5.920         0.019278   48.2692           443.4228
# 2          17.500         0.016760  141.6180          2097.2700
# 3          19.200         0.000000  182.0950           732.3800
# 4           8.930         0.000000   53.8614           994.7052
# ...           ...              ...       ...                ...
# 8518        6.865         0.056783  214.5218          2778.3834
# 8519        8.380         0.046982  108.1570           549.2850
# 8520       10.600         0.035186   85.1224          1193.1136
# 8521        7.210         0.145221  103.1332          1845.5976
# 8522       14.800         0.044878   75.4670           765.6700
#
#       Item_Identifier_0  Item_Identifier_1  Item_Identifier_2  \
# 0                     0                  1                  0
# 1                     1                  0                  0
# ...

# %%
Y
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
Y.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
Y['Item_Weight']=Y['Item_Weight'].fillna(Y['Item_Weight'].mean())
Y['Outlet_Size']=Y['Outlet_Size'].fillna('Medium')

# %%
Y['Item_Identifier']=Y['Item_Identifier'].apply(lambda x:x[0:2])

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
p=['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']
for i in p:
    Y[i]=l.fit_transform(Y[i])

# %%
Y
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1    20.750000                 1         0.007565
# 1                   1     8.300000                 4         0.038428
# 2                   2    14.600000                 1         0.099575
# 3                   1     7.315000                 1         0.015388
# 4                   1    12.695633                 2         0.118599
# ...               ...          ...               ...              ...
# 5676                1    10.500000                 2         0.013496
# 5677                1     7.600000                 2         0.142991
# 5678                2    10.000000                 1         0.073529
# 5679                1    15.300000                 2         0.000000
# 5680                1     9.500000                 2         0.104720
#
#                Item_Type  Item_MRP  Outlet_Identifier  \
# 0            Snack Foods  107.8622                  9
# ...

# %%
Y.drop(columns=(['Item_Type','Outlet_Establishment_Year']),inplace=True)

# %%
Y.head(3)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0                1        20.75                 1         0.007565  107.8622
# 1                1         8.30                 4         0.038428   87.3198
# 2                2        14.60                 1         0.099575  241.7538
#
#    Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                  9            1                     0            1
# 1                  2            1                     1            1
# 2                  0            1                     2            0

# %%
Y=pd.get_dummies(Y,columns=['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type'])
Y
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Identifier_0  \
# 0       20.750000         0.007565  107.8622                  0
# 1        8.300000         0.038428   87.3198                  0
# 2       14.600000         0.099575  241.7538                  0
# 3        7.315000         0.015388  155.0340                  0
# 4       12.695633         0.118599  234.2300                  0
# ...           ...              ...       ...                ...
# 5676    10.500000         0.013496  141.3154                  0
# 5677     7.600000         0.142991  169.1448                  0
# 5678    10.000000         0.073529  118.7440                  0
# 5679    15.300000         0.000000  214.6218                  0
# 5680     9.500000         0.104720   79.7960                  0
#
#       Item_Identifier_1  Item_Identifier_2  Item_Fat_Content_0  \
# 0                     1                  0                   0
# 1                     1                  0                   0
# ...

# %%
X_train=X.drop(['Item_Outlet_Sales'],axis=1)
y_train=X.Item_Outlet_Sales

# %%
X_test=Y

# %%
from sklearn.linear_model import Ridge
R=Ridge()
R_model=R.fit(X_train,y_train)

# %%
PRED_TEST=R_model.predict(X_test)
PRED_TRAIN=R_model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
MSE_TRAIN=mean_squared_error(y_train,PRED_TRAIN)
MSE_TRAIN
# Out:
# 1270740.9914386482

# %%
import numpy as np
RMSE_TRAIN=np.sqrt(MSE_TRAIN)
RMSE_TRAIN
# Out:
# 1127.2714808060427

# %%
R_SQ=R_model.score(X_train,y_train)
R_SQ
# Out:
# 0.5635890805841199

# %%
PRED_TEST=R_model.predict(X_test)
print(PRED_TEST)
# Out:
# [1847.75545373 1472.9777651  1876.93447225 ... 1809.59843491 3564.86798635
#  1268.10162815]

# %% [markdown]
# # lesson 3 slide 41
