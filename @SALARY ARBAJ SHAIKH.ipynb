# %%
import pandas as pd
pd.set_option('display.max_rows',500)

# %%
X=pd.read_csv(r"C:\Users\Arbaj\Downloads\Salaries.csv")
X
# Out:
# C:\Users\Arbaj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148648 entries, 0 to 148647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148648 non-null  int64
#  1   EmployeeName      148648 non-null  object
#  2   JobTitle          148648 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148648 non-null  float64
#  5   OtherPay          148648 non-null  float64
#  6   Benefits          112490 non-null  float64
#  7   TotalPay          148648 non-null  float64
#  8   TotalPayBenefits  148648 non-null  float64
#  9   Year              148648 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148648 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 14.7+ MB

# %%
X.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36158
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148648
# Agency                   0
# Status              110529
# dtype: int64

# %%
X1=X.drop(columns=['Notes','Status'],axis=1)
pd.set_option('display.max_rows',500)
pd.set_option('display.max_column',500)
print(X1.info())
X1.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148648 entries, 0 to 148647
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148648 non-null  int64
#  1   EmployeeName      148648 non-null  object
#  2   JobTitle          148648 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148648 non-null  float64
#  5   OtherPay          148648 non-null  float64
#  6   Benefits          112490 non-null  float64
#  7   TotalPay          148648 non-null  float64
#  8   TotalPayBenefits  148648 non-null  float64
#  9   Year              148648 non-null  int64
#  10  Agency            148648 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.5+ MB
# None
#      Id          EmployeeName  \
# 0     1        NATHANIEL FORD
# 1     2          GARY JIMENEZ
# 2     3        ALBERT PARDINI
# 3     4     CHRISTOPHER CHONG
# ...

# %%
X1.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36158
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
X1.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204880    -0.081487 -0.100403 -0.348950
# BasePay          -0.204880  1.000000     0.266742  0.285655  0.918028
# OvertimePay      -0.081487  0.266742     1.000000  0.316596  0.301199
# OtherPay         -0.100403  0.285655     0.316596  1.000000  0.233178
# Benefits         -0.348950  0.918028     0.301199  0.233178  1.000000
# TotalPay         -0.211421  0.954494     0.504858  0.470497  0.884097
# TotalPayBenefits -0.092125  0.946596     0.467981  0.422342  0.930139
# Year              0.968171  0.033750     0.027905 -0.002498 -0.043128
#
#                   TotalPay  TotalPayBenefits      Year
# Id               -0.211421         -0.092125  0.968171
# BasePay           0.954494          0.946596  0.033750
# OvertimePay       0.504858          0.467981  0.027905
# OtherPay          0.470497          0.422342 -0.002498
# Benefits          0.884097          0.930139 -0.043128
# ...

# %%
len(X1['Benefits'].unique())
# Out:
# 98465

# %%
X1['BasePay'].unique
# Out:
# <bound method Series.unique of 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148643         0.00
# 148644         0.00
# 148645         0.00
# 148646         0.00
# 148647         0.00
# Name: BasePay, Length: 148648, dtype: float64>

# %%
y=X1[X1['BasePay'].isnull()].index
X1.drop(y,inplace=True)

# %%
X1['Benefits']=lol CV

# %%
X1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148643                       Human Services Technician       0.00
# ...

# %%
X1.isna().any()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay             False
# OvertimePay         False
# OtherPay            False
# Benefits            False
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Agency              False
# dtype: bool

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(X2['Benefits'])
# Out:
# (array([2.6743e+04, 7.6410e+03, 2.3206e+04, 3.7354e+04, 1.2984e+04,
#         3.6940e+03, 7.2800e+02, 9.9000e+01, 3.5000e+01, 6.0000e+00]),
#  array([-3.3890000e+01,  9.6265650e+03,  1.9287020e+04,  2.8947475e+04,
#          3.8607930e+04,  4.8268385e+04,  5.7928840e+04,  6.7589295e+04,
#          7.7249750e+04,  8.6910205e+04,  9.6570660e+04]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(X1['Benefits'])
# Out:
# (array([4.3197e+04, 5.1437e+04, 3.5664e+04, 1.3825e+04, 3.4280e+03,
#         3.8700e+02, 8.9000e+01, 1.2000e+01, 2.0000e+00, 2.0000e+00]),
#  array([  2801.881086  ,  15248.4517668 ,  27695.02244759,  40141.59312839,
#          52588.16380918,  65034.73448998,  77481.30517077,  89927.87585157,
#         102374.44653236, 114821.01721316, 127267.58789395]),
#  <BarContainer object of 10 artists>)

# %%
print(len(X1['BasePay']))
print(len(X2['BasePay']))
# Out:
# 148043
# 148648

# %%
X2['Benefits'].fillna(X2['Benefits'].median)
# Out:
# 0         <bound method NDFrame._add_numeric_operations....
# 1         <bound method NDFrame._add_numeric_operations....
# 2         <bound method NDFrame._add_numeric_operations....
# 3         <bound method NDFrame._add_numeric_operations....
# 4         <bound method NDFrame._add_numeric_operations....
#                                 ...
# 148643                                                  0.0
# 148644                                                  0.0
# 148645                                                  0.0
# 148646                                                  0.0
# 148647                                                  0.0
# Name: Benefits, Length: 148648, dtype: object

# %%
y
# Out:
# Int64Index([ 81389,  84504,  84958,  90523,  90784,  90809,  91201,  92258,
#              97416,  98571,
#             ...
#             110519, 110520, 110521, 110522, 110523, 110524, 110525, 110526,
#             110527, 110528],
#            dtype='int64', length=605)

# %%
X1.iloc[81389,]
# Out:
# Id                               81393
# EmployeeName         Cristian A Vargas
# JobTitle            Sheet Metal Worker
# BasePay                       98213.41
# OvertimePay                   17454.48
# OtherPay                           0.0
# Benefits                  35779.643413
# TotalPay                     115667.89
# TotalPayBenefits             149932.67
# Year                              2013
# Agency                   San Francisco
# Name: 81390, dtype: object

# %%
X2.iloc[81390,]
# Out:
# Id                               81393
# EmployeeName         Cristian A Vargas
# JobTitle            Sheet Metal Worker
# BasePay                       98213.41
# OvertimePay                   17454.48
# OtherPay                           0.0
# Benefits                      34264.78
# TotalPay                     115667.89
# TotalPayBenefits             149932.67
# Year                              2013
# Agency                   San Francisco
# Name: 81390, dtype: object

# %%
X2=X1.copy('deep')

# %%
Total_Benifit=X2[['Id','TotalPayBenefits']]

# %%
BasePay=X2[['Id','BasePay']].dropna()

# %%
X_new=pd.merge(Total_Benifit,BasePay)
X_new.dropna()
# Out:
#             Id  TotalPayBenefits    BasePay
# 0            1         567595.43  167411.18
# 1            2         538909.28  155966.02
# 2            3         335279.91  212739.13
# 3            4         332343.61   77916.00
# 4            5         326373.19  134401.60
# ...        ...               ...        ...
# 148038  148646              0.00       0.00
# 148039  148648              0.00       0.00
# 148040  148649              0.00       0.00
# 148041  148650              0.00       0.00
# 148042  148654           -618.13       0.00
#
# [148043 rows x 3 columns]

# %%
BF=X2[['Id','Benefits']].dropna()

# %%
Z=pd.merge(X_new,BF)
Z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111885 entries, 0 to 111884
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                111885 non-null  int64
#  1   TotalPayBenefits  111885 non-null  float64
#  2   BasePay           111885 non-null  float64
#  3   Benefits          111885 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 4.3 MB

# %%
from sklearn import linear_model

# %%
i=Z[['TotalPayBenefits']]

# %%
j=Z.Benefits

# %%
reg=linear_model.LinearRegression()

# %%
model=reg.fit(i,j)

# %%
lol=model.predict(X_new[['TotalPayBenefits']])
len(lol)
# Out:
# 148043

# %%
u=X2['BasePay'].dropna()
v=X2

# %%
i=Z[['TotalPayBenefits','BasePay']]

# %%
print(X1.isna().any())

X1.head()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay             False
# OvertimePay         False
# OtherPay            False
# Benefits            False
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Agency              False
# dtype: bool
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay       Benefits   TotalPay  \
# 0  167411.18         0.00  400184.25  127267.587894  567595.43
# 1  155966.02    245131.88  137811.38  120983.961126  538909.28
# ...

# %%
import seaborn as sns

plt.subplots(1,1)
sns.boxplot(data=X1)
plt.xticks(rotation=90)
plt.show()
sns.boxplot(data=X1)
plt.ylim(0,200000)
plt.xticks(rotation=90)
plt.show()

# %%
Q1a=X1.quantile(0.25)
Q3a=X1.quantile(0.75)
IQRa=Q3a-Q1a
print(IQRa)
# Out:
# Id                  74627.000000
# BasePay             61103.700000
# OvertimePay          2982.320000
# OtherPay             4242.855000
# Benefits            19278.604317
# TotalPay            69071.150000
# TotalPayBenefits    88011.105000
# Year                    2.000000
# dtype: float64

# %%
Q1b=X1['OvertimePay'].quantile(0.25)
Q3b=X1['OvertimePay'].quantile(0.75)
IQRb=Q3b-Q1b
minb=Q1b-1.5*IQRb
maxb=Q3b+1.5*IQRb

print(minb,maxb)
# Out:
# -4473.4800000000005 7455.800000000001

# %%
X1['OvertimePay']=np.where(X1['OvertimePay']>= 11737.95,11737.95,X1['OvertimePay'])
X1['OvertimePay']=np.where(X1['OvertimePay']<= -7042.77,-7042.77,X1['OvertimePay'])

# %%
sns.boxplot(X1['OvertimePay'])
# Out:
# C:\Users\Arbaj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OvertimePay'>

# %%
sns.boxplot(X['OvertimePay'])
# Out:
# C:\Users\Arbaj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OvertimePay'>

# %%
print(X['OvertimePay'].quantile(0.70))
print(X['OvertimePay'].quantile(0.40))
# Out:
# 2982.3099999999995
# 0.0

# %%
X['OvertimePay']=np.where(X['OvertimePay']>= 11737.95,2982.32,X['OvertimePay'])
X['OvertimePay']=np.where(X['OvertimePay']<= -7042.77,0,X['OvertimePay'])

# %%
X
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148643                       Human Services Technician       0.00
# ...

# %%
uio=X.groupby('Year')['TotalPayBenefits'].sum()
uio
# Out:
# Year
# 2011    2.594113e+09
# 2012    3.696790e+09
# 2013    3.814772e+09
# 2014    3.821866e+09
# Name: TotalPayBenefits, dtype: float64

# %%
ww1=uio.iloc[3]-uio.iloc[0]

# %%
ww= (2.876911e+09)-(2.594113e+09)

# %%
print(f'total salary cost increased from year 2011 to 2014 is{ww1:.2f},approximately equals to {ww}')
# Out:
# total salary cost increased from year 2011 to 2014 is1227752749.88,approximately equals to 282798000.0

# %%
tyu=X.sort_values(['TotalPayBenefits','Year'],ascending=False)
tyu
# Out:
#             Id          EmployeeName  \
# 0            1        NATHANIEL FORD
# 1            2          GARY JIMENEZ
# 110529  110532           David Shinn
# 110530  110533            Amy P Hart
# 110531  110534  William J Coaker Jr.
# ...        ...                   ...
# 36157    36159    JOSEPHINE MCCREARY
# 110526  110529      Timothy E Gibson
# 110527  110530        Mark E Laherty
# 110528  110531         David P Kucia
# 148647  148654             Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 110529                                  Deputy Chief 3  129150.01
# 110530                               Asst Med Examiner  318835.49
# 110531                        Chief Investment Officer  257340.00
# ...                                                ...        ...
# ...

# %%
rt=tyu.iloc[0,1]
print(f'highest TotalPayBenefits across 4 year belongs to {rt}')
# Out:
# highest TotalPayBenefits across 4 year belongs to NATHANIEL FORD
