# %%
import pandas as pd
X=pd.read_csv(r"C:\Users\Arbaj\Downloads\mtcars.csv")
X
X=pd.DataFrame(X)
X.head(50)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
X.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
X['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(X['mpg']);
# Out:
# C:\Users\Arbaj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data=X);
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
Q3=X['mpg'].describe()[7]
Q1=X['mpg'].describe()[3]
Q3,Q1
# Out:
# (33.9, 10.4)

# %%
Q3=X['mpg'].describe()[6]
Q1=X['mpg'].describe()[4]
Q3,Q1
max1=(Q3+1.5*(Q3-Q1))
min1=(Q1-1.5*(Q3-Q1))
max1,min1
# Out:
# (33.8625, 4.362500000000001)

# %%
X_new=X[(X['mpg'].values>4.4) & (X['mpg'].values<33.86)]
X_new
# Out:
#                 model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5             Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6          Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7           Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8            Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9            Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10          Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11         Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
print(len(X['mpg']))
print(len(X_new))
# Out:
# 29
# 28

# %% [markdown]
# 1 outlier is removed from X['mpg']

# %%
A=X['wt'].skew()
print(A)
if A>0:
    print('positive skewed means mode<median<mean and outliers is greater than mean')
elif A==0:
    print('normal distribution')
else:
    print('negetive skewed means mode>median>mean and outliers is lesser than mean')
# Out:
# 0.4659161067929858
# positive skewed means mode<median<mean and outliers is greater than mean

# %%
X['wt'].describe()
# Out:
# count    32.000000
# mean      3.217250
# std       0.978457
# min       1.513000
# 25%       2.581250
# 50%       3.325000
# 75%       3.610000
# max       5.424000
# Name: wt, dtype: float64

# %%
len(X['wt'])
# Out:
# 32

# %%
Q1=X.quantile(0.25)
Q3=X.quantile(0.75)
IQR=(Q3-Q1)
print(IQR)
OUT=pd.DataFrame((X<(Q1-1.5*IQR)) | (X>(Q3+1.5*IQR)))
OUT.head(5)
# Out:
# mpg       7.37500
# cyl       4.00000
# disp    205.17500
# hp       83.50000
# drat      0.84000
# wt        1.02875
# qsec      2.00750
# vs        1.00000
# am        1.00000
# gear      1.00000
# carb      2.00000
# dtype: float64
# C:\Users\Arbaj\AppData\Local\Temp/ipykernel_15880/723396631.py:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   OUT=pd.DataFrame((X<(Q1-1.5*IQR)) | (X>(Q3+1.5*IQR)))
#       am   carb    cyl   disp   drat   gear     hp  model    mpg   qsec  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# ...

# %%
Q11=X['wt'].quantile(0.25)
Q31=X['wt'].quantile(0.75)
IQR1=Q31-Q11
print('low',Q11-1.5*IQR1)
print('high',Q31+1.5*IQR1)
# Out:
# low 1.0381249999999997
# high 5.153125

# %%
OUT1=X[(X['wt']<=1.04)|(X['wt']>=5.16)].index
X.drop(OUT1,inplace=True)
X['wt'].skew()
len(X['wt'])
# Out:
# 29

# %% [markdown]
# 3 outliers are removed from X['wt']

# %%
sns.boxplot(X['wt']);
# Out:
# C:\Users\Arbaj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#another try to remove outlier
print(len(X[X['wt'].values<4.1]))
X[X['wt'].values<4.1]
# Out:
# 29
#                 model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5             Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6          Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7           Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8            Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9            Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10          Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11         Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
print(df['Loan_amount'].quantile(0.50)) 
print(df['Loan_amount'].quantile(0.95)) 
df['Loan_amount'] = np.where(df['Loan_amount'] > 325, 140, df['Loan_amount'])
df.describe()


index = df[(df['Age'] >= 100)|(df['Age'] <= 18)].index
df.drop(index, inplace=True)
df['Age'].describe()





print(df['Income'].quantile(0.10))
print(df['Income'].quantile(0.90))


df["Income"] = np.where(df["Income"] <2960.0, 2960.0,df['Income'])
df["Income"] = np.where(df["Income"] >12681.0, 12681.0,df['Income'])
print(df['Income'].skew())

# %%
print(df['Income'].skew())
df['Income'].describe()



Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

print(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
